# %%
############################################################################
# hw04: Implementation of the Needleman-Wunsch Global Pairwise Alignment algorithm
############################################################################

def buildTable(X, Y, match=1, mismatch=-1, gap=-1):
    print("Sequence 1:", X)
    print("Sequence 2:", Y)
    # create table of zeros with dimension (1+|X|)-by-(1+|Y|)
    # X: vertical,  Y:horizontal
    opt = []
    
    #### Question (1) How to initialize the alignment table?   Please write your codes here!
    R = 1+Y
    C = 1+X
    Base_Table = [[0 for X in range(R)] for Y in range(C)]
    
    
    
    ####  Print out the initial table
    print("The intial alignment table is:")
    for row in opt:
          print(' '.join('%3d' % val for val in row))

    #### Question (2) How to initialize the first row and first column?   Please write your codes here!
    j = 0
    k = 0
    first_row = table[0][k]
    first_column = table[j][0]
    
    
    
    
    
    #### Question (3) How to calculate the score in each cell for each possible alignment?   Please write your codes here!
    if len(sequence1) != len(sequence2):
      return 'Error'
    final_score = 0
    for position in range(0, len(sequence1)):
      if sequence1[position] == '-' or sequence2[position] == '-':
        final_score = final_score + gap
      elif sequence1[position] != sequence2[position]:
        final_score = final_score + mismatch
      elif sequence1[position] == sequence2[position]:
        final_score = final_score + match
    
    
   
    
    #### Print the final table 
    print("The final alignment table is:")
    for row in opt:
      print(' '.join('%3d' % val for val in row))
    return opt

# %%
def TraceBack(X, Y, table, match=1, mismatch=-1, gap=-1):
    first = ''        # alignment for X
    second = ''       # alignment for Y
    glue = ''         # line showing matches/mismatches

    # start reconstruction at bottom-right of table
    j = len(X)
    k = len(Y)
    
    while j>0 or k>0:
        
        #### Question (5) What does the following 'if block' try to do? Please describe the codes using your words!
        ##
        ##   Write your answer here:
        ## The if statement says: if the length of the Column is greater than zero and if the table with the length of the column and row is equal to the length of the column-1 and row with the gap, 
        ## then the alignment for x gets subtracted by 1 and the rest remains neutral.
        ###########################################################################################################
        if j > 0 and table[j][k] == table[j-1][k] + gap:
            # option1 above; match X[j-1] with a gap in Y
            first  = X[j-1] + first
            second = '-' + second
            glue   = ' ' + glue
            j = j-1
        
        #### Question (6) What does the following 'elif block' try to do? Please describe the codes using your words!
        ##
        ##   Write your answer here:
        ## the else if states says that if the alignment for Y is less than zero and the table[j][k] is equal to the table[j] with a length of the row-1 + the gap, 
        ## then the alignment for x and the line showing matches+mismatches remains equal while the alignemtn for the row is subtracted by 1
        ###########################################################################################################
        
        elif k > 0 and table[j][k] == table[j][k-1] + gap:
            # option2 above; match gap in X with Y[k-1]
            first  = '-'  + first
            second = Y[k-1] + second
            glue   = ' '  + glue
            k = k-1
        
        #### Question (7) What does the following 'elif block' try to do? Please describe the codes using your words!
        ##
        ##   Write your answer here:
        ## this else if block states that if the length of the row and column are both less than one then column j will be subtracted by one and be added to the total 'first' and the row k will also be subtracted by 1 and added to 'second' 
        ## further on, the if statement is to designate a match since the condition is that both tables must be equal which indicates a match
        ## in the inner elif statement, this represents a mismatch since the condition is that they must not equal each other.
        ## this returns the best alignment at the end.
        ###########################################################################################################
        
        elif j>0 and k>0:
            # option1 above; match X[j-1] with Y[k-1]
            first =  X[j-1] + first
            second = Y[k-1] + second
            if X[j-1] == Y[k-1] and table[j][k] == table[j-1][k-1] + match:
              glue = '|' + glue   # designate match
            elif X[j-1] != Y[k-1] and table[j][k] == table[j-1][k-1] + mismatch:
                glue = '.' + glue   # designate mismatch
            j = j-1
            k = k-1
    print("The best alignment is:")
    print(first)
    print(glue)
    print(second)
    return first,glue,second
