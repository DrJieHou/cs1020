# %%
#Q1 Assume that we have our first DNA sequence that has a string as 'TTCATTTAT', which is comprised of four nucleotides (e.g. A, T, C, G). We would like to define a variable called 'DNA1', and assign the sequence to this variable. Then we need to print the variable by print("DNA1: ", DNA1)
#Please write your python codes for this activity.
DNA1 = 'TTCATTTAT'
print("DNA1 : ", DNA1)
#Q2 Again, we have our second DNA sequence that has a string as 'AAAAATAAA'. We would like to assign this sequence to another variable called 'DNA2', and print the variable by print("DNA2: ", DNA2).
#Please write your python codes for this activity.
DNA2 = 'AAAAATAAA'
print("DNA2 : ", DNA2)
#Q3 Now we have got two sequences, which were assigned two variables, DNA1, and DNA2. We would like to calculate the length of the two sequences and assign the length values to new variables, named DNA1_length and DNA2_length. Similarly, please print the values of the new variables.
#Please write your python codes for this activity
DNA1_length = len(DNA1)
DNA2_length = len(DNA2)
print(DNA1_length)
print(DNA2_length)
#Q4Based on the three steps above, we got two variables that store DNA sequences (DNA1, and DNA2), and also two variables that store the length of DNA sequences (DNA1_length and DNA2_length), We are curious on the equality of the length of two DNA sequences.
#Please write your python codes for the following questions:
#Q4.1 Is the length of DNA1 equal to the length of DNA2
DNA1_length == DNA2_length
print(DNA1_length == DNA2_length)
#Q4.2 Is the length of DNA1  not equal to the length of DNA2?
DNA1_length != DNA2_length
print(DNA1_length != DNA2_length)
#Q4.3 Is the length of DNA1 larger than the length of DNA2?
DNA1_length > DNA2_length
print(DNA1_length > DNA2_length)
#4.4 Is the length of DNA1 larger than the length of DNA2?
DNA1_length < DNA2_length
print(DNA1_length < DNA2_length)
#5Now let's do some sequence manipulations in python. For sequences, DNA1, and DNA2
#Please write your python codes for the following activities:
#5.1 What is the first letter of the first sequence, DNA1?
DNA1[0]
print(DNA1[0])
#5.2 What is the first letter of the second sequence, DNA2?
DNA2[0]
print(DNA2[0])
#5.3 What is the last letter of the first sequence, DNA1?
DNA1[8]
print(DNA1[8])
#5.4 What is the last letter of the first sequence, DNA2?
DNA2[8]
print(DNA2[8])
#5.5 Are the first letters of two sequences the same?
DNA1[0] == DNA2[0]
print(DNA1[0] == DNA2[0])
#5.6 Are the last letters of two sequences the same?
DNA1[8] == DNA2[8]
print(DNA1[8] == DNA2[8])
#5.7 What is the 5th letter of the first sequence, DNA1?
DNA1[4]
print(DNA1[4])
#5.8 What is the 5th letter of the second sequence, DNA2?
DNA2[4]
print(DNA2[4])
#5.9 What are the first 5 letters of the first sequence, DNA1?
DNA1[0 : 5]
print(DNA1[0 : 5])
#5.10 What are the first 5 letters of the second sequence, DNA2?
DNA2[0 : 5]
print(DNA2[0 : 5])
#5.11 What are the last 5 letters of the first sequence, DNA1?
DNA1[4 : 9]
print(DNA1[4 : 9])
#5.12 What are the last 5 letters of the second sequence, DNA2?
DNA2[4 : 9]
print(DNA2[4 : 9])
#5.13 How to concatenate the last 5 letters of the first sequence and the last 5 letters of the second sequence together?
DNA1[4 : 9] + DNA2[4 : 9]
print(DNA1[4 : 9] + DNA2[4 : 9])
#6 Let's continue with the sequence manipulations in python, but this time, we need to call some python's built-in functions. For sequences, DNA1, and DNA2
#Please write your python codes for the following activities:
#6.1 How many times does the character A appear in the first sequence DNA1? (hint: use str.count
DNA1.count('A')
#6.1 How many times does the character A appear in the first sequence DNA1? (hint: use str.count
DNA1.count('A')
print(DNA1.count('A'))
#6.2 How many times does the character A appear in the first sequence DNA2? (hint: use str.count() )
DNA2.count('A')
print(DNA2.count('A'))
#6.3 What is the index at which the first occurrence of the pattern AT begins in the first sequence DNA1? (hint: use str.index() )
DNA1.index('AT')
print(DNA1.index('AT'))
#6.4 What is the index at which the first occurrence of the pattern AT begins in the second sequence DNA2? (hint: use str.index() 
DNA2.index('AT')
print(DNA2.index('AT'))
# Out:
# DNA1 :  TTCATTTAT
# DNA2 :  AAAAATAAA
# 9
# 9
# True
# False
# False
# False
# T
# A
# T
# A
# False
# False
# T
# A
# TTCAT
# AAAAA
# TTTAT
# ATAAA
# TTTATATAAA
# 2
# 8
# 3
# 4
