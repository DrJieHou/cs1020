# %%
#Q1 Assume that we have 5 DNA motifs that have the following strings:
#TTCAT
#AATCATGA
#CCCG
#GGCATT
#CACGT
#which are comprised of four nucleotides (e.g. A, T, C, G). We would like to define a variable called 'DNA_motifs', and store these sequences in this variable using the data type list. Then we need to print the variable by print("DNA_motifs: ", DNA_motifs)
#Please write your python codes for this activity.
DNA_motifs = ['TTCAT', 'AATCATGA', 'CCCG', 'GGCATT', 'CACGT']
print("DNA_motifs: ", DNA_motifs)
# Out:
# DNA_motifs:  ['TTCAT', 'AATCATGA', 'CCCG', 'GGCATT', 'CACGT']

# %%
#Q2 Based on the defined list 'DNA_motifs', please write your python codes for the following activities:
DNA_motifs[0]
print(DNA_motifs[0])
#2.2 What is the last element of the list 'DNA_motifs'?
DNA_motifs[4]
print(DNA_motifs[4])
#2.3 What is the 3rd element of the list 'DNA_motifs'?
DNA_motifs[2]
print(DNA_motifs[2])
#2.4 What are the first 3 elements of the list 'DNA_motifs'?
DNA_motifs[0 : 3]
print(DNA_motifs[0 : 3])
#2.5 What are the last 2 elements of the list 'DNA_motifs'?
DNA_motifs[4 : 5]
print(DNA_motifs[4 : 5])
#2.6 Given the list 'DNA_motifs', how to concatenate the first 2 elements and the last element together?
DNA_motifs[0] + DNA_motifs[1] + DNA_motifs[4]
print(DNA_motifs[0] + DNA_motifs[1] + DNA_motifs[4])
# Out:
# TTCAT
# CACGT
# CCCG
# ['TTCAT', 'AATCATGA', 'CCCG']
# ['CACGT']
# TTCATAATCATGACACGT

# %%
#Q3 Based on the defined list 'DNA_motifs', 
#we need to calculate the length of each motif in this list. We need to use the 'for' loop to access each motif in the list and calculate the length. The expected outputs should be similar as follows:
print(DNA_motifs)
for item in DNA_motifs:
  print(item, '-', len(item))
# Out:
# ['TTCAT', 'AATCATGA', 'CCCG', 'GGCATT', 'CACGT']
# TTCAT - 5
# AATCATGA - 8
# CCCG - 4
# GGCATT - 6
# CACGT - 5

# %%
#Q4 Based on the defined list 'DNA_motifs', we need to find the longest motif in this list. We need to use the 'for' loop to access each motif in the list.
#Please write your python codes for this activity.
longest_motif = ''
longest_length = 0
for motif in DNA_motifs:
  length = len(motif)
  if length > longest_length:
    longest_motif = motif
    longest_length = length
    
  else : 
    break
print(len(longest_motif), '-', longest_motif)
# Out:
# 8 - AATCATGA

# %%
#Q5 Now let's practice more advanced programming using a list and dictionary. Based on the list 'DNA_motifs', let's define a dictionary 'DNA_motifs_length', where the key is each motif in the list 'DNA_motifs', and the value is its length.
#Please write your python codes for this activity  
DNA_motifs_lengths = {'TTCAT': '5',
                      'AATCATGA': '8',
                      'CCCG': '4',
                      'GGCATT': '6',
                      'CACGT': '5'}
print(DNA_motifs_lengths)
# Out:
# {'TTCAT': '5', 'AATCATGA': '8', 'CCCG': '4', 'GGCATT': '6', 'CACGT': '5'}

# %%
#Q6 Given the defined dictionary 'DNA_motifs_length', please write your python codes for the following activities.
#Add a new motif 'AAT' as a key into the dictionary, and assign its length as value
#Print out all the keys in the dictionary
#Print out all the values in the dictionary
#Print out all the items in the dictionary
#Check whether the key 'CCT' already exists in a dictionary
DNA_motifs_lengths['AAT'] = '3'
print(DNA_motifs_lengths.keys())
print(DNA_motifs_lengths.values())
print(DNA_motifs_lengths.items())
key_to_lookup = 'CCT'
if key_to_lookup in DNA_motifs_lengths:
  print("CCT exists")
else:
  print("CCT does not exist")
# Out:
# dict_keys(['TTCAT', 'AATCATGA', 'CCCG', 'GGCATT', 'CACGT', 'AAT', 'DNA_motifs[1] + DNA_motifs[3]', '', 'AATCATGAGGCATT'])
# dict_values(['5', '8', '4', '6', '5', '3', '14', '14', '14'])
# dict_items([('TTCAT', '5'), ('AATCATGA', '8'), ('CCCG', '4'), ('GGCATT', '6'), ('CACGT', '5'), ('AAT', '3'), ('DNA_motifs[1] + DNA_motifs[3]', '14'), ('', '14'), ('AATCATGAGGCATT', '14')])
# CCT does not exist

# %%
#Q7 Based on the defined list 'DNA_motifs', we are interested in the motifs that contain substring 'CAT', please write your python codes to print out these motifs. (hint: use while/for loop and if conditi
for motifs in DNA_motifs:
  if 'CAT' in motifs:
    print(motifs, '-', 'CAT is present in DNA string')
  else :
    print(motifs, '-', 'CAT is not found')
# Out:
# TTCAT - CAT is present in DNA string
# AATCATGA - CAT is present in DNA string
# CCCG - CAT is not found
# GGCATT - CAT is present in DNA string
# CACGT - CAT is not found

# %%
#Q8 Based on the defined list 'DNA_motifs', we are also interested in the motifs that have a length larger than 5, please write your python codes to print out these motifs. (hint: use while/for loop and if conditions)
for motifs in DNA_motifs:
  if len(motifs) > 5:
    print(motifs, '-', len(motifs), 'Greater than 5')
  else :
    print(motifs, '-', len(motifs), 'less than 5')
# Out:
# TTCAT - 5 less than 5
# AATCATGA - 8 Greater than 5
# CCCG - 4 less than 5
# GGCATT - 6 Greater than 5
# CACGT - 5 less than 5

# %%
#Q9 Based on the defined list 'DNA_motifs', we would like to replace the letter 'T' with 'U' for every motif and assign them to a new list called 'RNA_motifs'.
#Please write your python codes for this activity (hint: use for loop, string.replace() and list.append() function
RNA_motifs = []
for motif in DNA_motifs:
  RNA_motifs.append(motif.replace('T', 'U'))

print(RNA_motifs)
# Out:
# ['UUCAU', 'AAUCAUGA', 'CCCG', 'GGCAUU', 'CACGU']

# %%
#Q10 Based on the defined list 'DNA_motifs', we are also interested in the motifs that have a length larger than 5. 
#After we find the motifs, we need to concatenate them as a new string and add it as new key into dictionary 'DNA_motifs_length', where the value is the new sequence's length. Please write your python codes for this activity. (hint: use while/for loop and if conditions).
for motifs in DNA_motifs:
  if len(motifs) > 5:
    print(motifs, '-', len(motifs), 'Greater than 5')
  else :
    print(motifs, '-', len(motifs), 'less than 5')


print(len(DNA_motifs[1] + DNA_motifs[3]), DNA_motifs[1] + DNA_motifs[3] )
DNA_motifs_lengths ['AATCATGAGGCATT'] = '14'
print(DNA_motifs_lengths)
# Out:
# TTCAT - 5 less than 5
# AATCATGA - 8 Greater than 5
# CCCG - 4 less than 5
# GGCATT - 6 Greater than 5
# CACGT - 5 less than 5
# 14 AATCATGAGGCATT
# {'TTCAT': '5', 'AATCATGA': '8', 'CCCG': '4', 'GGCATT': '6', 'CACGT': '5', 'AAT': '3', 'DNA_motifs[1] + DNA_motifs[3]': '14', '': '14', 'AATCATGAGGCATT': '14'}
