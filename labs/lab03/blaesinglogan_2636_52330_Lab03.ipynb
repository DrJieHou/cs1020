# %%
DNA_motifs = ['TTCAT']
print('DNA Motifs: ', DNA_motifs)
# Out:
# DNA Motifs:  ['TTCAT']

# %%
#Q1. Write a python function to find the maximum number in a list. The function should accept any list of integers, and return the maximum values.
#After the function is defined, verifying your results using the built-in function 'max()'.
def find_maximum_value(input):
  maximum_number = float('-inf')
  for num in input:
    if num > maximum_number:
      maximum_number = num
  return maximum_number

# %%
find_maximum_value([1,3,2,5])
# Out:
# 5

# %%
#Q.2Write a python function to find the minimum number in a list. The function should accept any list of integers, and return the minimum value
#
def find_minimum_value(input):
  minimum_number = float('inf')
  for num in input:
    if num < minimum_number:
      minimum_number = num
    return minimum_number
find_minimum_value([1,3,2,5])
# Out:
# 1

# %%
#Q3. Write a python function to calculate the number of elements in a list. The function should accept any list of integers, and return the length of the list.
sample_list = (1,3,2,5)
def find_list_length(x):
  list_length = 0
  for num in x:
    list_length = list_length + 1
  return list_length
test_variable = (find_list_length(sample_list))
print(test_variable)
# Out:
# 4

# %%
#Q4. Write a python function to sum all numbers in a list. The function should accept any list of integers, and return the sum value.
sample_list = [1,3,2,5]
def sum_list_length(input):
 x=0
 for y in input:
   x=x+y
 return x

sum_list_length(sample_list)
# Out:
# 11

# %%
x = [1,2,3]
type(x)
x[1] = 2

# %%
#Q5. Assume that we have 5 DNA motifs that have the following strings
#which are comprised of four nucleotides (e.g. A, T, C, G). We would like to define a variable called 'DNA_motifs', and store these sequences in this variable using the data type list.
DNA_motifs = ['TTCAT, AATCATGA, CCCGC, GGCATT, CACGT']
print("DNA motifs: ", DNA_motifs)
# Out:
# DNA motifs:  ['TTCAT, AATCATGA, CCCGC, GGCATT, CACGT']

# %%
#Q6. Based on the defined list 'DNA_motifs', please write a python function to get motifs that contain string 'C?C' ('?' can be one of 'A', 'C', 'G', 'T').
DNA_motifs = ['TTCAT, AATCATGA, CCCGC, GGCATT, CACGT']
def DNA_find(x,letter):
  for e in x:
    if e[0] == letter and e[2] == letter:
      letter = 'C'
      print(e)
      DNA_find(DNA_motifs, "C")
